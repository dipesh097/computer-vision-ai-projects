# %% [markdown]
# # ***this is my second project of face regnition***

# %%
# !pip install face_recognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566166 sha256=68b75b26de69a89bda318bb18a333ce881fa55451cc8a15a264d52f9d095bce7
#   Stored in directory: /root/.cache/pip/wheels/8f/47/c8/f44c5aebb7507f7c8a2c0bd23151d732d0f0bd6884ad4ac635
# Successfully built face-recognition-models
# ...

# %%
import face_recognition
# import image
image=face_recognition.load_image_file("/content/WIN_20251225_12_27_05_Pro (2).jpg")

encoding=face_recognition.face_encodings(image)[0] #it converts face to 128 dimensition

# %%
# saving encoding
import numpy as np
np.save("image-encoding",encoding)

# %%
test_image=face_recognition.load_image_file("/content/WIN_20251225_12_27_05_Pro.jpg")

test_encoding=face_recognition.face_encodings(test_image)[0]
test_image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8094/1415866481.py in <cell line: 0>()
# ----> 1 test_image=face_recognition.load_image_file("/content/WIN_20251225_12_27_05_Pro.jpg")
#       2
#       3 test_encoding=face_recognition.face_encodings(test_image)[0]
#       4 test_image
#
# NameError: name 'face_recognition' is not defined

# %%
# compare both images

result=face_recognition.compare_faces([encoding], test_encoding)

print("is this youu? : ",result[0])
# Out:
# is this youu? :  True
